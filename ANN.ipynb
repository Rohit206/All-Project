# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit206/All-Project/blob/master/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import keras

# %%
# Artificial Neural Network


# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('/content/Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

## Concatenate the Data Frames

X=pd.concat([X,geography,gender],axis=1)

## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout


# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(6, kernel_initializer = 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)

# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['acc'])
plt.plot(model_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.5844 - accuracy: 0.7844 - val_loss: 0.5257 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.5237 - accuracy: 0.7872 - val_loss: 0.5003 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4971 - accuracy: 0.7918 - val_loss: 0.4849 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4716 - accuracy: 0.7965 - val_loss: 0.4730 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4536 - accuracy: 0.8049 - val_loss: 0.4638 - val_accuracy: 0.7955
# Epoch 6/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4490 - accuracy: 0.8014 - val_loss: 0.4565 - val_accuracy: 0.7963
# Epoch 7/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4503 - accuracy: 0.7974 - val_loss: 0.4507 - val_accuracy: 0.7970
# Epoch 8/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4478 - accuracy: 0.7918 - val_loss: 0.4458 - val_accuracy: 0.7986
# Epoch 9/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4393 - accuracy: 0.7989 - val_loss: 0.4420 - val_accuracy: 0.7997
# Epoch 10/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4424 - accuracy: 0.7961 - val_loss: 0.4391 - val_accuracy: 0.8012
# Epoch 11/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4310 - accuracy: 0.8068 - val_loss: 0.4367 - val_accuracy: 0.8035
# Epoch 12/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4342 - accuracy: 0.8101 - val_loss: 0.4348 - val_accuracy: 0.8065
# Epoch 13/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4292 - accuracy: 0.8079 - val_loss: 0.4332 - val_accuracy: 0.8099
# Epoch 14/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4266 - accuracy: 0.8103 - val_loss: 0.4320 - val_accuracy: 0.8129
# Epoch 15/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4164 - accuracy: 0.8231 - val_loss: 0.4309 - val_accuracy: 0.8095
# Epoch 16/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4233 - accuracy: 0.8141 - val_loss: 0.4300 - val_accuracy: 0.8107
# Epoch 17/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4183 - accuracy: 0.8196 - val_loss: 0.4292 - val_accuracy: 0.8099
# Epoch 18/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4221 - accuracy: 0.8183 - val_loss: 0.4286 - val_accuracy: 0.8114
# Epoch 19/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4144 - accuracy: 0.8193 - val_loss: 0.4282 - val_accuracy: 0.8118
# Epoch 20/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4039 - accuracy: 0.8268 - val_loss: 0.4277 - val_accuracy: 0.8114
# Epoch 21/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4132 - accuracy: 0.8235 - val_loss: 0.4274 - val_accuracy: 0.8122
# Epoch 22/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4193 - accuracy: 0.8230 - val_loss: 0.4270 - val_accuracy: 0.8118
# Epoch 23/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4157 - accuracy: 0.8167 - val_loss: 0.4268 - val_accuracy: 0.8111
# Epoch 24/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4182 - accuracy: 0.8199 - val_loss: 0.4264 - val_accuracy: 0.8103
# Epoch 25/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4038 - accuracy: 0.8311 - val_loss: 0.4262 - val_accuracy: 0.8114
# Epoch 26/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4082 - accuracy: 0.8224 - val_loss: 0.4254 - val_accuracy: 0.8122
# Epoch 27/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4103 - accuracy: 0.8250 - val_loss: 0.4252 - val_accuracy: 0.8122
# Epoch 28/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4005 - accuracy: 0.8351 - val_loss: 0.4249 - val_accuracy: 0.8133
# Epoch 29/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4266 - accuracy: 0.8198 - val_loss: 0.4245 - val_accuracy: 0.8118
# Epoch 30/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4147 - accuracy: 0.8246 - val_loss: 0.4242 - val_accuracy: 0.8126
# Epoch 31/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4181 - accuracy: 0.8212 - val_loss: 0.4236 - val_accuracy: 0.8122
# Epoch 32/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4077 - accuracy: 0.8311 - val_loss: 0.4231 - val_accuracy: 0.8137
# Epoch 33/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3960 - accuracy: 0.8343 - val_loss: 0.4222 - val_accuracy: 0.8148
# Epoch 34/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3971 - accuracy: 0.8359 - val_loss: 0.4216 - val_accuracy: 0.8156
# Epoch 35/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3954 - accuracy: 0.8366 - val_loss: 0.4209 - val_accuracy: 0.8148
# Epoch 36/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4081 - accuracy: 0.8322 - val_loss: 0.4195 - val_accuracy: 0.8152
# Epoch 37/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3907 - accuracy: 0.8429 - val_loss: 0.4185 - val_accuracy: 0.8160
# Epoch 38/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4006 - accuracy: 0.8323 - val_loss: 0.4172 - val_accuracy: 0.8164
# Epoch 39/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3944 - accuracy: 0.8384 - val_loss: 0.4162 - val_accuracy: 0.8164
# Epoch 40/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4027 - accuracy: 0.8325 - val_loss: 0.4150 - val_accuracy: 0.8171
# Epoch 41/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3923 - accuracy: 0.8352 - val_loss: 0.4136 - val_accuracy: 0.8190
# Epoch 42/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3938 - accuracy: 0.8357 - val_loss: 0.4122 - val_accuracy: 0.8198
# Epoch 43/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4107 - accuracy: 0.8269 - val_loss: 0.4107 - val_accuracy: 0.8213
# Epoch 44/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3907 - accuracy: 0.8396 - val_loss: 0.4088 - val_accuracy: 0.8220
# Epoch 45/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3993 - accuracy: 0.8303 - val_loss: 0.4068 - val_accuracy: 0.8247
# Epoch 46/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3878 - accuracy: 0.8430 - val_loss: 0.4050 - val_accuracy: 0.8239
# Epoch 47/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3868 - accuracy: 0.8428 - val_loss: 0.4026 - val_accuracy: 0.8251
# Epoch 48/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3819 - accuracy: 0.8431 - val_loss: 0.4007 - val_accuracy: 0.8273
# Epoch 49/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3921 - accuracy: 0.8370 - val_loss: 0.3983 - val_accuracy: 0.8289
# Epoch 50/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3713 - accuracy: 0.8519 - val_loss: 0.3964 - val_accuracy: 0.8285
# Epoch 51/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3718 - accuracy: 0.8541 - val_loss: 0.3941 - val_accuracy: 0.8300
# Epoch 52/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3699 - accuracy: 0.8508 - val_loss: 0.3921 - val_accuracy: 0.8319
# Epoch 53/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3676 - accuracy: 0.8484 - val_loss: 0.3898 - val_accuracy: 0.8342
# Epoch 54/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3734 - accuracy: 0.8493 - val_loss: 0.3880 - val_accuracy: 0.8334
# Epoch 55/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3812 - accuracy: 0.8418 - val_loss: 0.3859 - val_accuracy: 0.8357
# Epoch 56/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3613 - accuracy: 0.8515 - val_loss: 0.3842 - val_accuracy: 0.8391
# Epoch 57/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3522 - accuracy: 0.8600 - val_loss: 0.3822 - val_accuracy: 0.8398
# Epoch 58/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3717 - accuracy: 0.8522 - val_loss: 0.3804 - val_accuracy: 0.8406
# Epoch 59/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3629 - accuracy: 0.8524 - val_loss: 0.3790 - val_accuracy: 0.8421
# Epoch 60/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3594 - accuracy: 0.8572 - val_loss: 0.3776 - val_accuracy: 0.8436
# Epoch 61/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3617 - accuracy: 0.8576 - val_loss: 0.3759 - val_accuracy: 0.8440
# Epoch 62/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3459 - accuracy: 0.8617 - val_loss: 0.3749 - val_accuracy: 0.8451
# Epoch 63/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3508 - accuracy: 0.8576 - val_loss: 0.3738 - val_accuracy: 0.8463
# Epoch 64/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3278 - accuracy: 0.8699 - val_loss: 0.3730 - val_accuracy: 0.8474
# Epoch 65/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3581 - accuracy: 0.8507 - val_loss: 0.3718 - val_accuracy: 0.8504
# Epoch 66/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3430 - accuracy: 0.8603 - val_loss: 0.3715 - val_accuracy: 0.8470
# Epoch 67/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3392 - accuracy: 0.8687 - val_loss: 0.3705 - val_accuracy: 0.8501
# Epoch 68/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3421 - accuracy: 0.8609 - val_loss: 0.3700 - val_accuracy: 0.8497
# Epoch 69/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3464 - accuracy: 0.8613 - val_loss: 0.3690 - val_accuracy: 0.8508
# Epoch 70/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3621 - accuracy: 0.8567 - val_loss: 0.3684 - val_accuracy: 0.8501
# Epoch 71/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3372 - accuracy: 0.8667 - val_loss: 0.3677 - val_accuracy: 0.8504
# Epoch 72/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3450 - accuracy: 0.8597 - val_loss: 0.3675 - val_accuracy: 0.8512
# Epoch 73/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3439 - accuracy: 0.8602 - val_loss: 0.3670 - val_accuracy: 0.8519
# Epoch 74/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3319 - accuracy: 0.8628 - val_loss: 0.3671 - val_accuracy: 0.8512
# Epoch 75/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3398 - accuracy: 0.8620 - val_loss: 0.3663 - val_accuracy: 0.8512
# Epoch 76/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3451 - accuracy: 0.8609 - val_loss: 0.3661 - val_accuracy: 0.8535
# Epoch 77/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3364 - accuracy: 0.8693 - val_loss: 0.3659 - val_accuracy: 0.8550
# Epoch 78/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3439 - accuracy: 0.8613 - val_loss: 0.3663 - val_accuracy: 0.8501
# Epoch 79/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3509 - accuracy: 0.8591 - val_loss: 0.3657 - val_accuracy: 0.8531
# Epoch 80/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3367 - accuracy: 0.8622 - val_loss: 0.3655 - val_accuracy: 0.8523
# Epoch 81/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3484 - accuracy: 0.8621 - val_loss: 0.3651 - val_accuracy: 0.8519
# Epoch 82/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3284 - accuracy: 0.8638 - val_loss: 0.3650 - val_accuracy: 0.8512
# Epoch 83/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3249 - accuracy: 0.8676 - val_loss: 0.3649 - val_accuracy: 0.8519
# Epoch 84/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3421 - accuracy: 0.8585 - val_loss: 0.3644 - val_accuracy: 0.8542
# Epoch 85/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3469 - accuracy: 0.8606 - val_loss: 0.3646 - val_accuracy: 0.8516
# Epoch 86/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3459 - accuracy: 0.8608 - val_loss: 0.3641 - val_accuracy: 0.8523
# Epoch 87/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3338 - accuracy: 0.8630 - val_loss: 0.3644 - val_accuracy: 0.8516
# Epoch 88/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3292 - accuracy: 0.8682 - val_loss: 0.3639 - val_accuracy: 0.8535
# Epoch 89/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3491 - accuracy: 0.8593 - val_loss: 0.3636 - val_accuracy: 0.8538
# Epoch 90/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3384 - accuracy: 0.8638 - val_loss: 0.3634 - val_accuracy: 0.8527
# Epoch 91/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3376 - accuracy: 0.8634 - val_loss: 0.3636 - val_accuracy: 0.8535
# Epoch 92/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3319 - accuracy: 0.8658 - val_loss: 0.3636 - val_accuracy: 0.8527
# Epoch 93/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3325 - accuracy: 0.8662 - val_loss: 0.3640 - val_accuracy: 0.8512
# Epoch 94/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3328 - accuracy: 0.8650 - val_loss: 0.3635 - val_accuracy: 0.8519
# Epoch 95/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3422 - accuracy: 0.8564 - val_loss: 0.3636 - val_accuracy: 0.8508
# Epoch 96/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3305 - accuracy: 0.8693 - val_loss: 0.3636 - val_accuracy: 0.8508
# Epoch 97/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3348 - accuracy: 0.8656 - val_loss: 0.3631 - val_accuracy: 0.8516
# Epoch 98/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3403 - accuracy: 0.8638 - val_loss: 0.3632 - val_accuracy: 0.8531
# Epoch 99/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3325 - accuracy: 0.8669 - val_loss: 0.3632 - val_accuracy: 0.8516
# Epoch 100/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3492 - accuracy: 0.8564 - val_loss: 0.3635 - val_accuracy: 0.8519
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-6253b17d3725> in <module>()
#      66 print(model_history.history.keys())
#      67 # summarize history for accuracy
# ---> 68 plt.plot(model_history.history)
#      69 plt.plot(model_history.history['val_acc'])
#      70 plt.title('model accuracy')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# -> 1649             self.add_line(line)
#    1650         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1651         return lines
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1848             line.set_clip_path(self.patch)
#    1849
# -> 1850         self._update_line_limits(line)
#    1851         if not line.get_label():
#    1852             line.set_label('_line%d' % len(self.lines))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1870         Figures out the data limit of the given line, updating self.dataLim.
#    1871         """
# -> 1872         path = line.get_path()
#    1873         if path.vertices.size == 0:
#    1874             return
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/lines.py in recache(self, always)
#     673         if always or self._invalidy:
#     674             yconv = self.convert_yunits(self._yorig)
# --> 675             y = _to_unmasked_float_array(yconv).ravel()
#     676         else:
#     677             y = self._y
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1315         return np.ma.asarray(x, float).filled(np.nan)
#    1316     else:
# -> 1317         return np.asarray(x, float)
#    1318
#    1319
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# TypeError: float() argument must be a string or a number, not 'dict'

# %%
# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history["accuracy"])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
